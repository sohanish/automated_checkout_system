# %% [markdown]
# <a href="https://colab.research.google.com/github/sohanish/automated_checkout_system/blob/main/deepsort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #I will be now converting the yolov4 to tensorflow
# I am using google collab since my computer does not support cuda 10.2

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2022-06-15 00:52:24--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M  17.6MB/s    in 6.2s
#
# 2022-06-15 00:52:30 (13.2 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
# clone deepsort repo
# !git clone https://github.com/theAIGuysCode/yolov4-deepsort
# Out:
# Cloning into 'yolov4-deepsort'...
# remote: Enumerating objects: 143, done.
# remote: Total 143 (delta 0), reused 0 (delta 0), pack-reused 143
# Receiving objects: 100% (143/143), 76.84 MiB | 32.27 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %%
# %cd yolov4-deepsort/
# Out:
# /content/yolov4-deepsort

# %%
# !conda env create -f conda-gpu.yml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ...
# sip-4.19.8           | 274 KB    | : 100% 1.0/1 [00:00<00:00, 10.52it/s]
# kiwisolver-1.4.2     | 83 KB     | : 100% 1.0/1 [00:00<00:00, 20.27it/s]
# glib-2.63.1          | 2.9 MB    | : 100% 1.0/1 [00:00<00:00,  5.19it/s]
# freetype-2.11.0      | 618 KB    | : 100% 1.0/1 [00:00<00:00, 14.40it/s]
# certifi-2022.5.18.1  | 147 KB    | : 100% 1.0/1 [00:00<00:00, 18.61it/s]
# graphite2-1.3.14     | 97 KB     | : 100% 1.0/1 [00:00<00:00, 20.56it/s]
# libuuid-1.0.3        | 17 KB     | : 100% 1.0/1 [00:00<00:00, 17.28it/s]
# giflib-5.2.1         | 78 KB     | : 100% 1.0/1 [00:00<00:00, 18.02it/s]
# libwebp-1.2.2        | 80 KB     | : 100% 1.0/1 [00:00<00:00, 13.79it/s]
# expat-2.4.4          | 169 KB    | : 100% 1.0/1 [00:00<00:00, 18.04it/s]
# ...

# %%
# !pip install tensorflow-gpu==2.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#mounting my gdrive
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
#  CODM		   'College icbt'	   flyby       Projects   yolov4
# 'Colab Notebooks'  'Files and documents'  'My Drive'   SCL	  yolov4deep

# %%
# this is where my datasets are stored within my Google Drive 
# !ls /mydrive/yolov4deep
# Out:
# requirements-gpu.txt  yolov4-tiny.weights  yolov4.weights

# %%
# %cd yolov4-deepsort/
# Out:
# /content/yolov4-deepsort

# %%
# copy over both datasets into the root directory of the Colab VM 
# !cp /mydrive/yolov4deep/yolov4-tiny.weights ../data
# !cp /mydrive/yolov4deep/yolov4.weights ../data
# !cp /mydrive/yolov4deep/requirements-gpu1.txt ../

# %%
# !pip install -r requirements-gpu1.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install tensorflow==2.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 320.4 MB 52 kB/s
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.1
#     Uninstalling tensorflow-2.9.1:
#       Successfully uninstalled tensorflow-2.9.1
# ...

# %%
# !python save_model.py --model yolov4
# Out:
# 2022-06-15 00:06:58.350166: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-15 00:06:59.354784: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-06-15 00:06:59.383695: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-15 00:06:59.384291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-06-15 00:06:59.384329: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# %cd yolov4-deepsort/
# Out:
# /content/yolov4-deepsort

# %%
# !python save_model.py --weights ./data/yolov4-tiny.weights --output ./checkpoints/yolov4-tiny-416 --model yolov4 --tiny
# Out:
# 2022-06-15 00:41:39.381645: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-15 00:41:40.382301: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-06-15 00:41:40.412399: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-15 00:41:40.413063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-06-15 00:41:40.413109: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !zip -r /content/checkpoints.zip /content/yolov4-deepsort/checkpoints
# Out:
#   adding: content/yolov4-deepsort/checkpoints/ (stored 0%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-416/ (stored 0%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-416/assets/ (stored 0%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-416/variables/ (stored 0%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-416/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-416/variables/variables.index (deflated 81%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-416/saved_model.pb (deflated 92%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-tiny-416/ (stored 0%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-tiny-416/assets/ (stored 0%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-tiny-416/variables/ (stored 0%)
#   adding: content/yolov4-deepsort/checkpoints/yolov4-tiny-416/variables/variables.data-00000-of-00001 (deflated 7%)
# ...

# %%
# !cp checkpoints.zip /mydrive/yolov4deep/
